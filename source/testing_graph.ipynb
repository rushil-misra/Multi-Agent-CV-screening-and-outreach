# %%
from subgraph_interview import interview_subgraph

display(Image(interview_subgraph.get_graph().draw_mermaid_png()))

# %%
from graph2 import graph

display(Image(graph.get_graph().draw_mermaid_png()))
